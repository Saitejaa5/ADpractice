# %%
# !pip install mlxtend
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori,association_rules
# Out:
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    -------------------------------------- - 1.3/1.4 MB 77.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 3.2 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
titanic = pd.read_csv(r"C:\Users\Gaurav\Downloads\Titanic.csv")
titanic
# Out:
#      Class  Gender    Age Survived
# 0      3rd    Male  Child       No
# 1      3rd    Male  Child       No
# 2      3rd    Male  Child       No
# 3      3rd    Male  Child       No
# 4      3rd    Male  Child       No
# ...    ...     ...    ...      ...
# 2196  Crew  Female  Adult      Yes
# 2197  Crew  Female  Adult      Yes
# 2198  Crew  Female  Adult      Yes
# 2199  Crew  Female  Adult      Yes
# 2200  Crew  Female  Adult      Yes
#
# [2201 rows x 4 columns]

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2201 entries, 0 to 2200
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Class     2201 non-null   object
#  1   Gender    2201 non-null   object
#  2   Age       2201 non-null   object
#  3   Survived  2201 non-null   object
# dtypes: object(4)
# memory usage: 68.9+ KB

# %% [markdown]
# #### Observstions
# - All columns are object data type and categorical in nature
# - There are no null values
# - As the columns are categorical , we can adopt one hot encoding

# %%
counts = titanic['Class'].value_counts()
plt.bar(counts.index, counts.values)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# df = pd.get_dummies(titanic, dtype = int)
# df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2201 entries, 0 to 2200
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Class_1st      2201 non-null   int64
#  1   Class_2nd      2201 non-null   int64
#  2   Class_3rd      2201 non-null   int64
#  3   Class_Crew     2201 non-null   int64
#  4   Gender_Female  2201 non-null   int64
#  5   Gender_Male    2201 non-null   int64
#  6   Age_Adult      2201 non-null   int64
#  7   Age_Child      2201 non-null   int64
#  8   Survived_No    2201 non-null   int64
#  9   Survived_Yes   2201 non-null   int64
# dtypes: int64(10)
# memory usage: 172.1 KB

# %% [markdown]
# #### Apriori algorithm

# %%
frequent = apriori(df,min_support = 0.05,use_colnames=True,max_len = None)
import warnings
warnings.filterwarnings('ignore')

# %%
frequent
# Out:
#      support                                           itemsets
# 0   0.147660                                        (Class_1st)
# 1   0.129487                                        (Class_2nd)
# 2   0.320763                                        (Class_3rd)
# 3   0.402090                                       (Class_Crew)
# 4   0.213539                                    (Gender_Female)
# ..       ...                                                ...
# 58  0.053612   (Gender_Male, Age_Adult, Class_1st, Survived_No)
# 59  0.069968   (Gender_Male, Class_2nd, Age_Adult, Survived_No)
# 60  0.175829   (Gender_Male, Class_3rd, Age_Adult, Survived_No)
# 61  0.304407  (Gender_Male, Class_Crew, Age_Adult, Survived_No)
# 62  0.087233  (Survived_Yes, Gender_Male, Class_Crew, Age_Ad...
#
# [63 rows x 2 columns]

# %%
rules = association_rules(frequent ,metric = 'lift',min_threshold =1.0)
rules
# Out:
#                   antecedents                              consequents  \
# 0             (Gender_Female)                              (Class_1st)
# 1                 (Class_1st)                          (Gender_Female)
# 2                 (Age_Adult)                              (Class_1st)
# 3                 (Class_1st)                              (Age_Adult)
# 4              (Survived_Yes)                              (Class_1st)
# ..                        ...                                      ...
# 159  (Gender_Male, Age_Adult)               (Survived_Yes, Class_Crew)
# 160   (Class_Crew, Age_Adult)              (Survived_Yes, Gender_Male)
# 161             (Gender_Male)    (Survived_Yes, Class_Crew, Age_Adult)
# 162              (Class_Crew)   (Survived_Yes, Gender_Male, Age_Adult)
# 163               (Age_Adult)  (Survived_Yes, Gender_Male, Class_Crew)
#
#      antecedent support  consequent support   support  confidence      lift  \
# ...

# %%
rules.sort_values(by='lift',ascending = False)
# Out:
#                               antecedents  \
# 109            (Gender_Female, Age_Adult)
# 108             (Survived_Yes, Class_1st)
# 113                       (Gender_Female)
# 104  (Survived_Yes, Age_Adult, Class_1st)
# 33              (Survived_Yes, Class_1st)
# ..                                    ...
# 24                            (Age_Adult)
# 20                          (Gender_Male)
# 21                            (Age_Adult)
# 119              (Gender_Male, Class_1st)
# 120              (Age_Adult, Survived_No)
#
#                               consequents  antecedent support  \
# 109             (Survived_Yes, Class_1st)            0.193094
# 108            (Gender_Female, Age_Adult)            0.092231
# 113  (Survived_Yes, Age_Adult, Class_1st)            0.213539
# 104                       (Gender_Female)            0.089505
# 33                        (Gender_Female)            0.092231
# ..                                    ...                 ...
# ...

# %% [markdown]
# ### Conclusion
# - The Females travelling in 1st class were among the most survived.

# %%
rules[['support','confidence','lift']].hist(figsize=(15,7))
plt.show()

# %%
plt.scatter(rules['support'], rules['confidence'])
plt.show()

# %%
plt.scatter(rules['confidence'], rules['lift'])
plt.show()

# %%
rules[rules["consequents"] == ({"supervised_Yes"})]
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, representativity, leverage, conviction, zhangs_metric, jaccard, certainty, kulczynski]
# Index: []
