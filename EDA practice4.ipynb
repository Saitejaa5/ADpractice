# %%
# !pip install matplotlib seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
data = pd.read_csv(r"C:\Users\Gaurav\Downloads\data_clean.csv")
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
# Display the first few rows of the dataset
#print("First 5 rows of the dataset:")
print(data.head())

# Number of rows and columns
#print("\nNumber of rows and columns:")
print(f"Rows: {data.shape[0]}, Columns: {data.shape[1]}")

# Column names and their data types
#print("\nColumn names and data types:")
print(data.dtypes)

# Check for null values
#print("\nNull values in each column:")
print(data.isnull().sum())

# Summary statistics for numeric columns
#print("\nSummary statistics for numeric columns:")
print(data.describe())
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0           1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1           2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2           3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3           4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4           5    NaN      NaN  14.3     56     5    5  2010    56       S
# Rows: 158, Columns: 10
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64
# ...

# %%
print(type(data))
print(data.shape)
print(data.size)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)
# 1580

# %%
data1 = data.drop(['Unnamed: 0', "Temp C"], axis = 1)
data1
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
data1['Month'] = pd.to_numeric(data1['Month'], errors='coerce')


data1[data1.duplicated(keep = False)]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3    9.0   28  2010    75       S
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
data1[data1.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
data1.drop_duplicates(keep = 'first',inplace = True)
data1
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    9.0   27  2010    77       S
# 157   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %% [markdown]
# **Imoute the missing values**

# %%
data1.isnull().sum()
# Out:
# Ozone      38
# Solar.R     7
# Wind        0
# Month       1
# Day         0
# Year        0
# Temp        0
# Weather     3
# dtype: int64

# %%
cols = data1.columns
colors = ['yellow', 'black']
sns.heatmap(data1[cols].isnull(), cmap=sns.color_palette(colors, as_cmap=True), cbar=True)
# Out:
# <Axes: >

# %%
median_ozone = data1["Ozone"].median()
mean_ozone = data1["Ozone"].mean()
print("Median of Ozone: ", median_ozone)
print("Mean of Ozone: ", mean_ozone)
# Out:
# Median of Ozone:  31.0
# Mean of Ozone:  41.81512605042017

# %%
data1['Ozone'] = data1['Ozone'].fillna(median_ozone)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    3
# dtype: int64

# %%
data1.head()
# Out:
#    Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0   41.0    190.0   7.4    5.0    1  2010    67       S
# 1   36.0    118.0   8.0    5.0    2  2010    72       C
# 2   12.0    149.0  12.6    5.0    3  2010    74      PS
# 3   18.0    313.0  11.5    5.0    4  2010    62       S
# 4   31.0      NaN  14.3    5.0    5  2010    56       S

# %%
print(data1['Weather'].value_counts())
mode_weather = data1["Weather"].mode()[0]
print(mode_weather)
# Out:
# Weather
# S     58
# C     49
# PS    47
# Name: count, dtype: int64
# S

# %%
data1["Weather"] = data1["Weather"].fillna(mode_weather)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Month      1
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
print(data1['Month'].value_counts())
mode_month = data1["Month"].mode()[0]
print(mode_month)
# Out:
# Month
# 9.0    33
# 5.0    31
# 7.0    31
# 8.0    31
# 6.0    30
# Name: count, dtype: int64
# 9.0

# %%
data1["Month"] = data1["Month"].fillna(mode_month)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
print(data1['Solar.R'].value_counts())
mode_Solar = data1["Solar.R"].mode()[0]
print(mode_Solar)
# Out:
# Solar.R
# 259.0    4
# 238.0    4
# 223.0    3
# 190.0    3
# 220.0    3
#         ..
# 27.0     1
# 49.0     1
# 14.0     1
# 201.0    1
# 20.0     1
# Name: count, Length: 117, dtype: int64
# 238.0

# %%
data1["Solar.R"] = data1["Solar.R"].fillna(mode_Solar)
data1.isnull().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Month      0
# Day        0
# Year       0
# Temp       0
# Weather    0
# dtype: int64

# %%
data1.reset_index(drop=True)
data1
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4     31.0    238.0  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 152   20.0    223.0  11.5    9.0   30  2010    68       S
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155   31.0    145.0  13.2    9.0   27  2010    77       S
# 157   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [157 rows x 8 columns]

# %% [markdown]
# ***Dectection of outliers in the columns***

# %%
# Select numeric columns only
numeric_cols = data1.select_dtypes(include=[np.number])

# Plot histograms and box plots for each numeric column
num_cols = len(numeric_cols.columns)
fig, axes = plt.subplots(num_cols, 2, figsize=(12, 5 * num_cols))

for i, col in enumerate(numeric_cols.columns):
    # Histogram
    sns.histplot(data1[col], kde=True, ax=axes[i, 0])
    axes[i, 0].set_title(f'Histogram of {col}')
    axes[i, 0].set_xlabel(col)
    axes[i, 0].set_ylabel('Frequency')
    
    # Boxplot
    sns.boxplot(x=data1[col], ax=axes[i, 1])
    axes[i, 1].set_title(f'Boxplot of {col}')
    axes[i, 1].set_xlabel(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# ***Method1 : using histogram and boxplots***

# %%
fig,axes=plt.subplots(2,1,figsize=(8,6),gridspec_kw={'height_ratios':[1,3]})
sns.boxplot(data=data1["Ozone"],ax=axes[0],color='skyblue',width=0.5,orient='h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")

sns.histplot(data1["Ozone"],kde=True,ax=axes[1],color='Purple',bins=30)
axes[1].set_title("Histogram with KDE")
axes[1].set_xlabel("Ozone Levels")
axes[1].set_ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# ***Observation***
# - The ozone column has extreme values beyond 81 as seen from box plot
# - The same is confirmed from the below right = skewed histogram

# %%
sns.violinplot(data=data1['Ozone'],color='pink')
plt.title('Violin Plot')
plt.show()

# %%
sns.violinplot(data=data1['Solar.R'],color='lightpink')
plt.title('Violin Plot')
plt.show()

# %%
#plt.figure(figsize=(6,2))
#boxplot_data = plt.boxplot(data1["Ozone"], vert=False)
data1["Ozone"].describe()
# Out:
# count    157.000000
# mean      39.197452
# std       28.781992
# min        1.000000
# 25%       21.000000
# 50%       31.000000
# 75%       45.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
mu = data1["Ozone"].describe()[1]
sigma = data1["Ozone"].describe()[2]

for x in data1["Ozone"]:
    if ((x < (mu - 3*sigma)) or (x > (mu + 3*sigma))):
        print(x)
# Out:
# 135.0
# 168.0
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_12068\2701659469.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mu = data1["Ozone"].describe()[1]
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_12068\2701659469.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sigma = data1["Ozone"].describe()[2]

# %%
import scipy.stats as stats

plt.figure(figsize=(8,6))
stats.probplot(data1["Ozone"],dist ="norm" , plot=plt)
plt.title("Q-Q plot for Outlier Detection " , fontsize=14)
plt.xlabel("Theoretical Quantiles", fontsize = 12)
# Out:
# Text(0.5, 0, 'Theoretical Quantiles')

# %%
#create a figure for violin plot 

sns.violinplot(data = data1["Ozone"] , color = 'lightgreen')
plt.title("Violin Plot")

plt.show()

# %%
sns.violinplot(data=data1, x = "Weather", y = "Ozone",palette="Set2")
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_12068\1977849919.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=data1, x = "Weather", y = "Ozone",palette="Set2")
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.swarmplot(data = data1, x = "Weather" , y = "Ozone" , color = "Orange" , palette="set2" , size = 6)
plt.show()
# Out:
# C:\Users\Gaurav\AppData\Local\Temp\ipykernel_12068\2112074367.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data = data1, x = "Weather" , y = "Ozone" , color = "Orange" , palette="set2" , size = 6)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\palettes.py:235, in color_palette(palette, n_colors, desat, as_cmap)
#     233 try:
#     234     # Perhaps a named matplotlib colormap?
# --> 235     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236 except (ValueError, KeyError):  # Error class changed in mpl36
#
# ...

# %%
plt.figure(figsize=(10, 6))
sns.swarmplot(data=data1, x="Weather", y="Ozone", hue="Weather", palette="Set2", size=6)


plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.stripplot(data=data1, x="Weather", y="Ozone", hue="Weather", palette="Set2", size=6)

# Show the plot
plt.show()

# %%
sns.kdeplot(data=data1["Ozone"], fill=True, color="blue")
sns.rugplot(data=data1["Ozone"], color="black")

# %%
sns.boxplot(data=data1, x = "Weather" , y = "Ozone")

# %%
plt.scatter(data1["Wind"], data1["Temp"])

# %%
data1["Wind"].corr(data1["Temp"])

# %%
data1_numeric = data1.iloc[:,[0,1,2,6]]
data1_numeric
# Out:
#      Ozone  Solar.R  Wind  Temp
# 0     41.0    190.0   7.4    67
# 1     36.0    118.0   8.0    72
# 2     12.0    149.0  12.6    74
# 3     18.0    313.0  11.5    62
# 4     31.0    238.0  14.3    56
# ..     ...      ...   ...   ...
# 152   20.0    223.0  11.5    68
# 153   41.0    190.0   7.4    67
# 154   30.0    193.0   6.9    70
# 155   31.0    145.0  13.2    77
# 157   18.0    131.0   8.0    76
#
# [157 rows x 4 columns]

# %%
data1_numeric.corr()
# Out:
#             Ozone   Solar.R      Wind      Temp
# Ozone    1.000000  0.295569 -0.523738  0.597087
# Solar.R  0.295569  1.000000 -0.062587  0.245066
# Wind    -0.523738 -0.062587  1.000000 -0.441228
# Temp     0.597087  0.245066 -0.441228  1.000000

# %% [markdown]
# ***Observations***
# - the highest correlation strength is observed between Ozone and Temperature(0.597087)
# - the next higher correlation strength is observed between Ozone and wind(-0.523738)
# - The least correlation strength is observed between solar and wind(-0.055874)

# %%
sns.pairplot(data1_numeric)

# %% [markdown]
# ***Transformations***

# %%
data2=pd.get_dummies(data1,columns=['Month','Weather'])
data2
# Out:
#      Ozone  Solar.R  Wind  Day  Year  Temp  Month_5.0  Month_6.0  Month_7.0  \
# 0     41.0    190.0   7.4    1  2010    67       True      False      False
# 1     36.0    118.0   8.0    2  2010    72       True      False      False
# 2     12.0    149.0  12.6    3  2010    74       True      False      False
# 3     18.0    313.0  11.5    4  2010    62       True      False      False
# 4     31.0    238.0  14.3    5  2010    56       True      False      False
# ..     ...      ...   ...  ...   ...   ...        ...        ...        ...
# 152   20.0    223.0  11.5   30  2010    68      False      False      False
# 153   41.0    190.0   7.4    1  2010    67       True      False      False
# 154   30.0    193.0   6.9   26  2010    70      False      False      False
# 155   31.0    145.0  13.2   27  2010    77      False      False      False
# 157   18.0    131.0   8.0   29  2010    76      False      False      False
#
# ...
